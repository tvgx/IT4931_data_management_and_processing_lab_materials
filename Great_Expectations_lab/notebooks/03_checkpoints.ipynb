# %% [markdown]
# # Lab 3: Checkpoints - Automated Validation Workflows
#
# ## 🎯 Objectives
# - Hiểu Checkpoints là gì
# - Tạo và cấu hình Checkpoints
# - Validation Actions
# - Run checkpoints
# - Handle validation results
#
# ## 📋 Prerequisites
# - Hoàn thành Lab 1-2
# - Expectations đã được tạo

# %%
import great_expectations as gx
import os
from pathlib import Path

project_root = Path('.').resolve()
if project_root.name != 'Great_Expectations_lab':
    project_root = project_root.parent / 'Great_Expectations_lab'

os.chdir(project_root)

try:
    context = gx.get_context()
    
    print("🎯 Checkpoints Overview:")
    print("=" * 60)
    print("""
Checkpoints combine:
- Data Asset (what to validate)
- Expectation Suite (what to check)
- Validation Actions (what to do with results)

Benefits:
- Reusable validation workflows
- Automated execution
- Result storage
- Integration với pipelines
""")
    
    print("\n💡 To create checkpoint:")
    print("  great_expectations checkpoint new")
    print("  Or use context.add_checkpoint()")
    
except Exception as e:
    print(f"⚠️  Error: {e}")
    print("💡 Initialize GE context first")
