# %% [markdown]
# # Lab 5: Data Quality với Great Expectations
#
# ## 🎯 Objectives
# - GE expectations trên processed data
# - Checkpoints và validations
# - Data quality monitoring
# - Alerts và notifications

# %%
print("🔮 Great Expectations trong Lakehouse:")
print("=" * 60)
print("""
Validation Points:

1. At Ingestion (Bronze):
   - Validate raw data quality
   - Check schema compliance
   - Data completeness checks

2. After Processing (Silver):
   - Validate cleaned data
   - Business rule checks
   - Data consistency

3. After Transformation (Gold/Marts):
   - Validate dbt outputs
   - Final data quality checks
   - Ready for analytics

Integration:
- GE checkpoints run trong Airflow
- Fail pipeline nếu validation fails
- Store validation results
- Generate data docs
""")
print("=" * 60)
