# %% [markdown]
# # Lab 7: End-to-End Pipeline - Complete Data Lakehouse Implementation
#
# ## 🎯 Objectives
# - Build complete end-to-end data pipeline
# - Integrate tất cả components
# - Test và validate pipeline
# - Performance optimization
# - Production best practices
#
# ## 📋 Prerequisites
# - Hoàn thành Lab 1-6
# - Tất cả services đang chạy
# - Hiểu tất cả components

# %%
print("🎯 Complete End-to-End Pipeline:")
print("=" * 60)
print("""
Pipeline Flow:

1. Data Sources
   ↓
2. Kafka (Ingestion)
   ↓
3. Spark Streaming (Real-time Processing)
   ↓
4. Iceberg Bronze Tables (Raw Storage)
   ↓
5. Spark Batch (Cleaning)
   ↓
6. Iceberg Silver Tables (Cleaned Data)
   ↓
7. dbt (Transformation)
   ↓
8. Iceberg Gold Tables (Marts)
   ↓
9. Great Expectations (Validation)
   ↓
10. Analytics Layer

All orchestrated by Airflow!
""")
print("=" * 60)

print("\n💡 Key Integration Points:")
print("  - Kafka → Spark: Structured Streaming")
print("  - Spark → Iceberg: Write operations")
print("  - Iceberg → dbt: Read operations")
print("  - dbt → GE: Validation")
print("  - All → Airflow: Orchestration")
