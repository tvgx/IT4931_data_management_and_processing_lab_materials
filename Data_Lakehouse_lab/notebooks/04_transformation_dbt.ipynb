# %% [markdown]
# # Lab 4: Transformation với dbt
#
# ## 🎯 Objectives
# - dbt models trên Iceberg tables
# - Staging → Intermediate → Marts
# - Business logic transformations
# - dbt tests

# %%
print("📊 dbt Transformation trong Lakehouse:")
print("=" * 60)
print("""
1. Read từ Iceberg tables:
   select * from {{ source('iceberg', 'bronze_events') }}

2. Transform với dbt:
   - Staging: Clean raw data
   - Intermediate: Business logic
   - Marts: Final analytics tables

3. Write back to Iceberg:
   - dbt creates tables trong Iceberg catalog
   - Materialized as tables hoặc views

4. Integration:
   - dbt reads từ Iceberg Silver/Gold
   - Creates marts trong Iceberg
   - GE validates dbt outputs
""")
print("=" * 60)
